# %%
import Cartesian2Polar
from PIL import Image

# %%
im = Image.open("D:\\gitcustomers\\Pill-CBIR-Keras-CNN\\data\\test\\images\\229.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=297x297 at 0x1C6B4C33AC8>

# %%
pim = Cartesian2Polar.project_cartesian_image_into_polar_image(im, origin=None)
pim
# Out:
# <PIL.Image.Image image mode=RGB size=297x297 at 0x1C6B4B35A20>

# %%
pim.crop(box=(0,0,pim.width,150))
# Out:
# <PIL.Image.Image image mode=RGB size=297x150 at 0x1C6B4B35588>

# %%
def cart_to_polar_by_filepath(src,dest,crop_height=10000, crop_width=10000, rotate_count=0):

    cart_im = Image.open(src)
    polar_im = Cartesian2Polar.project_cartesian_image_into_polar_image(cart_im, origin=None)
    
    crop_height=min(crop_height,polar_im.height)
    crop_width=min(crop_width,polar_im.width)
    cropped_polar_im = polar_im.crop(box=(0,0,crop_width,crop_height))
    
    cropped_polar_im.save(dest)
    
    
    
    if (rotate_count>0):
        fname, fext = os.path.splitext(dest)
        #print(fname + "  ---  " + fext)
        for x in range(rotate_count):
            angle=randint(0,360)
            
            rotated_cart_im = cart_im.rotate(angle)
            rotated_polar_im = Cartesian2Polar.project_cartesian_image_into_polar_image(rotated_cart_im, origin=None)
            cropped_rotated_polar_im = rotated_polar_im.crop(box=(0,0,crop_width,crop_height))
            rotated_fname = fname + "_" + str(angle)
            rotated_dest = rotated_fname + fext
            cropped_rotated_polar_im.save(rotated_dest)

# %%
import os, shutil
from random import randint

root_src_dir = 'data_grayscale'    #Path/Location of the source directory
root_dst_dir = 'data_grayscale_with_rotations\\'  #Path to the destination folder

for src_dir, dirs, files in os.walk(root_src_dir):
    dst_dir = src_dir.replace(root_src_dir, root_dst_dir, 1)
    if not os.path.exists(dst_dir):
        os.makedirs(dst_dir)
    for file_ in files:
        src_file = os.path.join(src_dir, file_)
        dst_file = os.path.join(dst_dir, file_)
        if os.path.exists(dst_file):
            os.remove(dst_file)
        #shutil.copy(src_file, dst_dir)
        fname, fext = os.path.splitext(src_file)
        if (fext == '.jpg'):
            cart_to_polar_by_filepath(src_file,dst_file,crop_height=150, rotate_count=3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-42406feb3554> in <module>()
#      17         fname, fext = os.path.splitext(src_file)
#      18         if (fext == '.jpg'):
# ---> 19             cart_to_polar_by_filepath(src_file,dst_file,crop_height=150, rotate_count=3)
#      20
#
# <ipython-input-2-7d0fe6e0a40b> in cart_to_polar_by_filepath(src, dest, crop_height, crop_width, rotate_count)
#       2
#       3     cart_im = Image.open(src)
# ----> 4     polar_im = Cartesian2Polar.project_cartesian_image_into_polar_image(cart_im, origin=None)
#       5
#       6     crop_height=min(crop_height,polar_im.height)
#
# ~/git/Keras_CNN_with_Polar/Cartesian2Polar.py in project_cartesian_image_into_polar_image(image, origin)
#      81     image.convert('RGB')
#      82     data = np.array(image)
# ---> 83     polar_grid, r, theta = reproject_image_into_polar(data, origin)
#      84     polar_image = Image.fromarray(polar_grid)
#      85     return polar_image
#
# ~/git/Keras_CNN_with_Polar/Cartesian2Polar.py in reproject_image_into_polar(data, origin)
#      70     bands = []
#      71     for band in data.T:
# ---> 72         zi = sp.ndimage.map_coordinates(band, coords, order=1)
#      73         bands.append(zi.reshape((nx, ny)))
#      74     output = np.dstack(bands)
#
# /anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py in map_coordinates(input, coordinates, output, order, mode, cval, prefilter)
#     317         raise RuntimeError('input and output rank must be > 0')
#     318     if coordinates.shape[0] != input.ndim:
# --> 319         raise RuntimeError('invalid shape for coordinate array')
#     320     mode = _ni_support._extend_mode_to_code(mode)
#     321     if prefilter and order > 1:
#
# RuntimeError: invalid shape for coordinate array
